# %%
import pandas as pd
schedule_path = '/Users/phamgiahung/Documents/project_AI/langgraph_agent/data/schedule.csv'
schedule = pd.DataFrame(columns= ['content'])
schedule.index.name= 'date'
schedule.to_csv(schedule_path)

# %%
import os
print(os.getcwd())
# Out:
# /Users/phamgiahung/Documents/project_AI/langgraph_agent

# %%
import sys
print(sys.executable)
# Out:
# /Users/phamgiahung/Documents/project_AI/langgraph_agent/.venv/bin/python3
